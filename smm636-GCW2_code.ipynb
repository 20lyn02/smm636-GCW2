# %% [markdown]
# # __0. Initialization__

# %% [markdown]
# ## 0.1. Libraries

# %%
# CORE
import numpy as np
import pandas as pd
from collections import Counter

# VISUALISATIONS
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# PROCESSING & PCA
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


# CLUSTERING
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import linkage, fcluster, dendrogram
from scipy.cluster.hierarchy import cut_tree
from scipy.spatial.distance import pdist
from sklearn.metrics import silhouette_score, silhouette_samples

# WARNINGS
import warnings

# %% [markdown]
# ## 0.2. Functions

# %%
# Silhouette score plotting for K-means
def plot_silhouette(ax, silhouette_vals, labels, title, n_clusters, data):
    # Initial y location
    y_lower = 0
    legend_patches = []  # Store handles for legend
    for i in range(n_clusters):
        # SScores for the current cluster and sort them for better visualization
        cluster_silhouette_vals = silhouette_vals[labels == i]
        cluster_silhouette_vals.sort()
        # Size of the cluster
        size_cluster = cluster_silhouette_vals.shape[0]
        y_upper = y_lower + size_cluster
        # Plot the cluster
        ax.fill_betweenx(np.arange(y_lower, y_upper), 0, cluster_silhouette_vals, alpha=0.7, label=f"{size_cluster}")
        # Make sure the next cluster start above current one
        y_lower = y_upper
    
    # Plot the Silhouette score line
    ax.axvline(x=silhouette_score(data, labels), color="red", linestyle="--")

    # Plot labels
    ax.set_xlabel("Silhouette Coefficient Values")
    ax.set_ylabel("Cluster Members")
    ax.set_title(title)
    ax.set_ylim(0, 50)
    ax.legend(title='Cluster Size', loc='lower right')

# %%
# Silhouette score plotting for Hierarchical
def plot_silhouette_hclust(ax, silhouette_vals, labels, title, n_clusters, data):
    # Initial y location
    y_lower = 0
    legend_patches = []  # Store handles for legend
    for i in range(1, n_clusters+1):
        # SScores for the current cluster and sort them for better visualization
        cluster_silhouette_vals = silhouette_vals[labels == i]
        cluster_silhouette_vals.sort()
        # Size of the cluster
        size_cluster = cluster_silhouette_vals.shape[0]
        y_upper = y_lower + size_cluster
        # Plot the cluster
        ax.fill_betweenx(np.arange(y_lower, y_upper), 0, cluster_silhouette_vals, alpha=0.7, label=f"{size_cluster}")
        # Make sure the next cluster start above current one
        y_lower = y_upper
    
    # Plot the Silhouette score line
    ax.axvline(x=silhouette_score(data, labels), color="red", linestyle="--")

    # Plot labels
    ax.set_xlabel("Silhouette Coefficient Values")
    ax.set_ylabel("Cluster Members")
    ax.set_title(title)
    ax.set_ylim(0, 50)
    ax.legend(title='Cluster Size', loc='lower right')

# %%
# Convert comma-separated strings to lists
def split_and_strip(series):
    return series.str.split(',').apply(lambda lst: [item.strip() for item in lst if item])

# %% [markdown]
# ## 0.3. MISC

# %%
# Remove warnings
warnings.filterwarnings("ignore")
# Set random seed
rng = 42

# %% [markdown]
# # __1. DATA__

# %% [markdown]
# ## 1.1. Data Processing

# %%
# Load the dataset and preview the dataset
df = pd.read_csv("IMDB-Movies.csv")
df.head()
# Out:
#    Unnamed: 0            Title                    Genre  \
# 0           1  The Dark Knight       Action,Crime,Drama
# 1           2        Inception  Action,Adventure,Sci-Fi
# 2           3           Dangal   Action,Biography,Drama
# 3           4     Interstellar   Adventure,Drama,Sci-Fi
# 4           5    Kimi no na wa  Animation,Drama,Fantasy
#
#                                          Description           Director  \
# 0  When the menace known as the Joker wreaks havo...  Christopher Nolan
# 1  A thief, who steals corporate secrets through ...  Christopher Nolan
# 2  Former wrestler Mahavir Singh Phogat and his t...      Nitesh Tiwari
# 3  A team of explorers travel through a wormhole ...  Christopher Nolan
# 4  Two strangers find themselves linked in a biza...     Makoto Shinkai
#
#                                               Actors  Year  Runtime..Minutes.  \
# 0  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008                152
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010                148
# 2  Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,...  2016                161
# 3  Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014                169
# 4  Ryûnosuke Kamiki, Mone Kamishiraishi, Ryô Nari...  2016                106
#
#    Rating    Votes  Revenue..Millions.
# 0     9.0  1791916              533.32
# 1     8.8  1583625              292.57
# 2     8.8    48969               11.15
# 3     8.6  1047747              187.99
# 4     8.6    34110                4.68

# %%
# Check for missiing values
print(df.isnull().sum(), df.shape)
# Out:
# Unnamed: 0            0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime..Minutes.     0
# Rating                0
# Votes                 0
# Revenue..Millions.    3
# dtype: int64 (50, 11)

# %% [markdown]
# We have considered filling the missing revenue values with values obtained from IMDB website, however, without knowing the date of when the data was collected, it may have created unfair results for the 3 movies. Additionally, we have attempted to fill the missing revenue values with revenue means, however, we were able to acheive better results with just removing them.

# %%
# Remove observation with missing values
df.dropna(inplace=True)
# Check if they were removed
print(df.isnull().sum(), df.shape)
# Out:
# Unnamed: 0            0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime..Minutes.     0
# Rating                0
# Votes                 0
# Revenue..Millions.    0
# dtype: int64 (47, 11)

# %%
# Only keep numerical columns excluding (year)
imdb = df.select_dtypes(include='number').drop(columns=['Year', 'Unnamed: 0'])
imdb.head()
# Out:
#    Runtime..Minutes.  Rating    Votes  Revenue..Millions.
# 0                152     9.0  1791916              533.32
# 1                148     8.8  1583625              292.57
# 2                161     8.8    48969               11.15
# 3                169     8.6  1047747              187.99
# 4                106     8.6    34110                4.68

# %%
# Check means and standard deviations
print(f"Means:\n{np.round(imdb.mean(), 2)}")
print(f"\nStandard Deviations:\n{np.round(imdb.std(), 2)}")
# Out:
# Means:
# Runtime..Minutes.        135.02
# Rating                     8.30
# Votes                 544978.00
# Revenue..Millions.       157.81
# dtype: float64
#
# Standard Deviations:
# Runtime..Minutes.         21.61
# Rating                     0.22
# Votes                 402909.35
# Revenue..Millions.       195.10
# dtype: float64

# %%
#Standardization to ensure comparability, as both PCA and clustering are sensitive to scale.
scaler = StandardScaler()
scaler.fit(imdb)
# Apply transform scale returns
imdb_scaled = scaler.transform(imdb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # scale features
# ----> 2 scaler = StandardScaler()
#       3 scaler.fit(imdb)
#       4 # Apply transform scale returns
#
# NameError: name 'StandardScaler' is not defined

# %% [markdown]
# ## 1.2. EDA

# %%
# Plot histograms to visualize the distribution of each numerical feature
imdb.hist(bins=30, figsize=(9, 6), edgecolor='black')
plt.suptitle("Distribution of Numerical Features", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Plot a heatmap of the correlation matrix to explore linear relationships between numerical features
plt.figure(figsize=(8, 6))
sns.heatmap(imdb.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of Features", fontsize=16)
plt.show()

# %% [markdown]
# Votes and revenue exhibit a moderate positive correlation. This positive relationship is evident in the PCA visualization, where the vectors for votes and revenue appear close together, forming a small angle between them.

# %%
# Generate boxplots for each numerical feature to detect the influence of potential outliers
plt.figure(figsize=(8, 4))
for i, col in enumerate(imdb.columns, 1):
    plt.subplot(2, int(np.ceil(len(imdb.columns) / 2)), i)
    sns.boxplot(y=imdb[col])
    plt.title(col)
plt.tight_layout()
plt.suptitle("Boxplots of Numerical Features", fontsize=15, y=1.03)
plt.show()

# %% [markdown]
# # __2. PCA__

# %% [markdown]
# ## 2.1. Choosing the numebr of Principal Component

# %%
# Apply PCA to reduce to all components
pca_full = PCA()
pcomp_full = pca_full.fit_transform(imdb_scaled)

# %%
# Display the proportion and cumulative variance explained by each component
print("Explained Variance by Principal Components:")
cumulative_var = 0

for i, ratio in enumerate(pca_full.explained_variance_ratio_, start=1):
    cumulative_var += ratio
    print(f"PC{i} Variance Captured: {ratio:.2%} (Cumulative: {cumulative_var:.2%})")

# PVE and cumulative PVE plots
pca_temp = PCA()
pca_temp.fit(imdb_scaled)

fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# PVE Plot
ax = axes[0]
ticks = np.arange(pca_temp.n_components_) + 1
ax.plot(ticks, pca_temp.explained_variance_ratio_, marker='o')
ax.set_xlabel('Principal Component')
ax.set_ylabel('Proportion of Variance Explained (PVE)')
ax.set_title('PVE by Component')

# Cumulative PVE Plot
ax = axes[1]
ax.plot(ticks, pca_temp.explained_variance_ratio_.cumsum(), marker='o')
ax.set_xlabel('Principal Component')
ax.set_ylabel('Cumulative PVE')
ax.set_title('Cumulative PVE')

plt.tight_layout()
plt.show()
# Out:
# Explained Variance by Principal Components:
# PC1 Variance Captured: 43.19% (Cumulative: 43.19%)
# PC2 Variance Captured: 29.62% (Cumulative: 72.81%)
# PC3 Variance Captured: 19.64% (Cumulative: 92.45%)
# PC4 Variance Captured: 7.55% (Cumulative: 100.00%)

# %% [markdown]
# From the Elbow plot above, we can see that 90% variance captured is reached at PC3 (PC3: 92.45% vs PC2: 72.81%), therefore we are going to use PC1,2,3 for our analysis and models.

# %%
# Apply PCA to reduce to 3 components
pca = PCA(n_components=3)
pcomp = pca.fit_transform(imdb_scaled)

# Get component scores
df_pca = pd.DataFrame(data=pcomp, index=imdb.index, columns=['PC1', 'PC2', 'PC3'])
df_pca.head()
# Out:
#         PC1       PC2       PC3
# 0  4.772326  0.462205 -1.178936
# 1  3.335473  0.733901 -0.957936
# 2  0.107999  2.447912 -0.839995
# 3  1.999436  1.405362  0.235787
# 4 -1.044810  0.428793 -2.057119

# %%
# Get component loadings for each feture
loadings = pca.components_.T
df_pca_load = pd.DataFrame(data=loadings, index=imdb.columns, columns=['PC1', 'PC2', 'PC3'])
df_pca_load
# Out:
#                          PC1       PC2       PC3
# Runtime..Minutes.   0.274519  0.627404  0.708938
# Rating              0.444094  0.472413 -0.674149
# Votes               0.693758 -0.115823  0.002863
# Revenue..Millions.  0.496105 -0.608091  0.207177

# %%
# Combine PC scores with movie titles
df_pca_titles = pd.concat([df['Title'], df_pca], axis=1)
df_pca_titles.head()
# Out:
#              Title       PC1       PC2       PC3
# 0  The Dark Knight  4.772326  0.462205 -1.178936
# 1        Inception  3.335473  0.733901 -0.957936
# 2           Dangal  0.107999  2.447912 -0.839995
# 3     Interstellar  1.999436  1.405362  0.235787
# 4    Kimi no na wa -1.044810  0.428793 -2.057119

# %% [markdown]
# ## 2.2. Plotting the PCs agaist each other

# %% [markdown]
# #### 2.2.1. 2D plots

# %%
# Get the variables for the model
components = df_pca[['PC1', 'PC2', 'PC3']].values
loadings = pca.components_.T
features = imdb.columns

# Only plot PC1 vs PC2 and PC1 vs PC3
component_pairs = [(0, 1), (0, 2)]

# Loop through each selected PC pair
for x_id, y_id in component_pairs:
    plt.figure(figsize=(10, 7))
    
    # Plot the data points in 2D PCA space
    plt.scatter(components[:, x_id], components[:, y_id], 
                alpha=0.6, 
                color='gray')
    
    # Overlay arrows for each feature’s loading on 2D PC axis
    for i, feature in enumerate(features):
        # Add the arrows
        plt.arrow(0, 0,
                  loadings[i, x_id] * 1.5,
                  loadings[i, y_id] * 1.5,
                  color='red',
                  head_width=0.02)
        # Add the arrows feature names
        plt.text(loadings[i, x_id] * 1.6,
                 loadings[i, y_id] * 1.6,
                 feature,
                 color='blue',
                 ha='center',
                 va='center',
                 fontsize=10)

    # Plot Labels
    plt.xlabel(f'PC{x_id+1}')
    plt.ylabel(f'PC{y_id+1}')
    plt.title(f'PCA Biplot: PC{x_id+1} vs PC{y_id+1}')
    plt.grid(True)
    plt.axhline(0, color='black', lw=0.5)  # horizontal axis
    plt.axvline(0, color='black', lw=0.5)  # vertical axis
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### 2.2.2. 3D Plot

# %%
# Base PCA scatter plot (gray points) with movie titles on hover
fig = px.scatter_3d(
    df_pca_titles,
    x='PC1',
    y='PC2',
    z='PC3',
    opacity=0.7,
    color_discrete_sequence=['gray'],
    hover_name='Title',
    title='3D PCA Plot',
    labels={'x': 'PC1', 'y': 'PC2', 'z': 'PC3'}
)

# Define colors for arrows
colors = px.colors.qualitative.D3

# Sort features alphabetically
sorted_features = sorted(zip(features, loadings), key=lambda x: x[0])

# Add arrows for sorted features
for i, (feature, vec) in enumerate(sorted_features):
    fig.add_trace(go.Scatter3d(
        x=[0, vec[0] * 2],
        y=[0, vec[1] * 2],
        z=[0, vec[2] * 2],
        mode='lines+text',
        name=feature,
        text=[None, feature],
        textposition='top center',
        line=dict(color=colors[i % len(colors)], width=4)
    ))

# Layout settings
fig.update_layout(
    width=1000,
    height=800
)
fig.show()

# %% [markdown]
# # __3. K-Means Clustering__

# %% [markdown]
# ## 3.1. Elbow method to find optimal numebr of K-clusters

# %%
# Set the range of clusters to check
k_range = range(1, 17)

# Elbow for PCA Data (first 3 PCs)
inertias = []
for k in k_range:
    km = KMeans(n_clusters=k, n_init=20, random_state=rng)
    km.fit(df_pca[['PC1', 'PC2', 'PC3']])
    inertias.append(km.inertia_)

# Initiatea the plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(k_range, inertias, marker='s')

# Highlight possible best number of clusters
ax.plot(6, inertias[5], 'ro', markersize=8)  # point of interest 1
ax.plot(7, inertias[6], 'ro', markersize=8)  # point of interest 2 

# Plot Labels
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method: Raw Data vs PCA Data')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# From the plot above, we can see that the best number of cluster is around 6 or 7, therefore we will test further to choose best one.

# %% [markdown]
# ## 3.2. Silhouette Scores for K-Means Clustering

# %%
# Lis the numebr of cluster to test
n_clusters_list = [ 5, 6, 7, 8]  # Add 5 and 8 for safety

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

print("=== K-means Silhouette Scores===")
for n_clusters in n_clusters_list:
    
    # K-Means Clustering
    kmeans = KMeans(n_clusters=n_clusters, n_init=20, random_state=rng)
    labels_kmeans = kmeans.fit_predict(df_pca)
    silhouette_kmeans = silhouette_score(df_pca, labels_kmeans)
    silhouette_vals_kmeans = silhouette_samples(df_pca, labels_kmeans)

    # Print the Silhouette values for comparison
    print(f"Clusters={n_clusters}: {silhouette_kmeans}")

    # Create subplots for side-by-side comparison
    if n_clusters == 6:
        plot_silhouette(axes[0], silhouette_vals_kmeans, np.array(labels_kmeans), "Silhouette Plot - K-Means 6", 6, df_pca)
    elif n_clusters ==7:
        plot_silhouette(axes[1], silhouette_vals_kmeans, np.array(labels_kmeans), "Silhouette Plot - K-Means 7", 7, df_pca)

    
plt.tight_layout()
plt.show()
# Out:
# === K-means Silhouette Scores===
# Clusters=5: 0.3128564770257323
# Clusters=6: 0.37614963224373915
# Clusters=7: 0.3714189652249551
# Clusters=8: 0.33564512956841897

# %% [markdown]
# We can see from these scores that the best number of clusters to choose is 6, with 7 being close second

# %% [markdown]
# ## 3.3. Plotting the PCs agaist each other with K-Means Clustering

# %% [markdown]
# #### 3.3.1. 2D Plots

# %%
# Create DataFrame copy from PCA components
df_pca_copy0 = df_pca.copy()

# Fit KMeans on 2D PCA space
kmeans_pca = KMeans(n_clusters=6, n_init=20, random_state=rng)
clusters_pca = kmeans_pca.fit_predict(df_pca_copy0)

# Add cluster labels and movie titles
df_pca_copy0['Cluster'] = clusters_pca
df_pca_copy0['Title'] = df_pca_titles['Title']

# Define the specific PCA component pairs to plot
pca_pairs = [('PC1', 'PC2'), ('PC1', 'PC3')]

# Plot selected PCA component pairs
for x_comp, y_comp in pca_pairs:
    plt.figure(figsize=(8, 6))
    sns.scatterplot(
        x=x_comp, y=y_comp,
        hue='Cluster',
        palette='tab10',
        data=df_pca_copy0,
        s=80,
        alpha=0.8
    )

    # Add movie titles as text labels
    for _, row in df_pca_copy0.iterrows():
        plt.text(row[x_comp]+0.02, row[y_comp]+0.02, row['Title'], fontsize=7, alpha=0.6)

    # Plot Labels
    plt.title(f'Movie Clusters in PCA Space: {x_comp} vs {y_comp}')
    plt.xlabel(x_comp)
    plt.ylabel(y_comp)
    plt.legend(title='Cluster', loc='upper right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### 3.3.2. 3D Plot

# %%
# Create a copy of df_pca_clusters for plotting
df_pca_copy1 = df_pca_copy0.copy()

# Map cluster labels and ensure proper sort order in legend
unique_clusters = sorted(df_pca_copy1['Cluster'].unique())
cluster_map = {old: new for new, old in enumerate(unique_clusters, start=0)}
df_pca_copy1['Cluster'] = df_pca_copy1['Cluster'].map(cluster_map).astype(str)

# Create sorted list for legend order
sorted_cluster_labels = [str(i) for i in sorted(cluster_map.values())]

# Create 3D scatter plot
fig = px.scatter_3d(
    df_pca_copy1, 
    x='PC1', y='PC2', z='PC3',
    color='Cluster',
    title='Interactive 3D K-Means Clustering in PCA Space',
    labels={'Cluster': 'K-Means Cluster'},
    hover_name='Title',
    opacity=0.8,
    category_orders={'Cluster': sorted_cluster_labels}  # Force legend order
)

# Adjust sizes
fig.update_traces(marker=dict(size=10))
fig.update_layout(
    width=1000,
    height=800
)
fig.show()

# %% [markdown]
# # __4. Hierarchical Clustering__

# %% [markdown]
# ## 4.1. Perform and Plot the Hierarchical Clustering using Complete/ Average/ Single linkage methods

# %%
# Define varaibles for the models
titles = df_pca_titles['Title']
linkage_methods = ['complete', 'average', 'single']

# Initialise subplot for each linkage method
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Generate dendograms for each linkage method
for ax, method in zip(axes, linkage_methods):
    dist_matrix = pdist(df_pca, metric='euclidean')
    linkage_matrix = linkage(dist_matrix, method=method)

    dendrogram(linkage_matrix,
                   labels=np.array(titles),
                    ax=ax,
                    leaf_rotation=90,
                    leaf_font_size=8,    
                    color_threshold=0.0,
                    above_threshold_color='black'
    )

    # Plot Labels
    ax.set_title(f'{method.capitalize()} Linkage')
    ax.set_xlabel('Movies')
    ax.set_ylabel('Distance')
plt.tight_layout()
plt.show()

# %% [markdown]
# From the 3 dendograms above, we can see that the best performing models are using 'Complete' & 'Average' linkage methods, therefore we will focus closer on them.

# %% [markdown]
# ## 4.2. Silhouette Scores for Hierarchical Clustering

# %%
# Defeine cluster list and titles
n_clusters_list = [6,7,8]

# Hierarchical Clustering - Complete Linkage with various clusters
dist_matrix = pdist(df_pca, metric='euclidean')
linkage_complete = linkage(dist_matrix, method='complete')
print("=== COMPLE LINKAGE ===")
for n_clusters in n_clusters_list:
    labels_complete = fcluster(linkage_complete, t=n_clusters, criterion='maxclust')
    silhouette_complete = silhouette_score(df_pca, labels_complete)
    
    # Store silhouette scores
    print(f"Clusters={n_clusters}: {silhouette_complete}")

# Hierarchical Clustering - Average Linkage with various cutoffs
linkage_average = linkage(dist_matrix, method='average')
print("\n=== AVERAGE LINKAGE ===")
for n_clusters in n_clusters_list:
    labels_average = fcluster(linkage_average, t=n_clusters, criterion='maxclust')
    silhouette_average = silhouette_score(df_pca, labels_average)
    
    # Store silhouette scores
    print(f"Clusters={n_clusters}: {silhouette_average}")
# Out:
# === COMPLE LINKAGE ===
# Clusters=6: 0.2889753576423668
# Clusters=7: 0.3433114304951801
# Clusters=8: 0.33337213125594417
#
# === AVERAGE LINKAGE ===
# Clusters=6: 0.32328521405352323
# Clusters=7: 0.37812233673994305
# Clusters=8: 0.35345358733646387

# %% [markdown]
# ## 4.3. Choosing best HClust model

# %%
# Best model found
dist_matrix_best = pdist(df_pca, metric='euclidean')
linkage_matrix_best = linkage(dist_matrix_best, method='average')

fig, ax = plt.subplots(figsize=(8, 8))

# Plot the dendogram
dendrogram(
    linkage_matrix_best,
    labels=np.array(titles),
    ax=ax,
    leaf_rotation=90,
    leaf_font_size=8,
    color_threshold=2.0,  # cut-off line for 7 clusters
    above_threshold_color='black'
)

# Plot labes
ax.set_title('Average Linkage Dendrogram (Cut Line at Distance = 2)')
ax.set_xlabel('Movies')
ax.set_ylabel('Distance')
ax.axhline(2.0, c='red', linewidth=2, linestyle='--')  # Add cut-off line on the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4.4. Plotting PCs against each other with Hierarchical Clustering

# %% [markdown]
# #### 4.4.1. 2D Plots

# %%
# Create DataFrame copy from PCA components
df_pca_copy2 = df_pca.copy()

# Generate cluster labels from hierarchical clustering
hclust_labels = fcluster(linkage_matrix_best, t=7.0, criterion='maxclust')
df_pca_copy2['Cluster'] = hclust_labels
df_pca_copy2['Title'] = df_pca_titles['Title']

# Define the specific component pairs to plot
pca_pairs = [('PC1', 'PC2'), ('PC1', 'PC3')]

# Plot selected PCA component pairs
for x_comp, y_comp in pca_pairs:
    plt.figure(figsize=(8, 6))
    sns.scatterplot(
        x=x_comp, y=y_comp,
        hue='Cluster',
        palette='tab10',
        data=df_pca_copy2,
        s=80,
        alpha=0.8
    )

    # Add movie titles as text labels
    for _, row in df_pca_copy2.iterrows():
        plt.text(row[x_comp] + 0.02, row[y_comp] + 0.02, row['Title'], fontsize=7, alpha=0.6)

    # Plot labels
    plt.title(f'HClust Movie Clusters in PCA Space: {x_comp} vs {y_comp}')
    plt.xlabel(x_comp)
    plt.ylabel(y_comp)
    plt.legend(title='Cluster', loc='upper right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### 4.4.2. 3D Plot

# %%
# Define the best hierarchical model found
hclust_best = fcluster(linkage_matrix_best, t=7, criterion='maxclust')

# Assign clusters and prepare labels
df_pca_copy4 = df_pca_titles.copy()
df_pca_copy4['Hierarchical_Cluster'] = pd.Series(hclust_best, index=df_pca_copy4.index).astype(str)

# Create ordered cluster labels for legend
unique_clusters = sorted(np.unique(hclust_best))
sorted_cluster_labels = [str(i) for i in unique_clusters]

# Plot the 3D PC plot with hierarchical  clustering
fig = px.scatter_3d(
    df_pca_copy4,
    x='PC1', y='PC2', z='PC3',
    color='Hierarchical_Cluster',
    hover_name='Title',
    title='3D Hierarchical Clustering Scatter Plot (Cut at Distance = 2.0, Number of Clusters = 7)',
    labels={'Hierarchical_Cluster': 'Cluster'},
    category_orders={'Hierarchical_Cluster': sorted_cluster_labels},
    opacity=0.8
)

# Adjust sizes
fig.update_traces(marker=dict(size=10))
fig.update_layout(width=1000, height=800)
fig.show()

# %% [markdown]
# # __5. Compare K-Means & Hierarchical Clustering Methods__

# %% [markdown]
# ## 5.1. Hierarchical vs KMeans Comparison Table

# %%
# Hierarchical clustering
linkage_comp = linkage(imdb_scaled, method='average')
comp_cut = cut_tree(linkage_comp, n_clusters=7).reshape(-1)

# KMeans clustering
kmeans_comp = KMeans(n_clusters=6, random_state=rng, n_init=20)
comp_labels = kmeans_comp.fit_predict(imdb_scaled)

# Crosstab comparison
pd.crosstab(pd.Series(comp_cut, name='HClust'),
            pd.Series(comp_labels, name='KMeans'))
# Out:
# KMeans  0   1  2  3  4  5
# HClust
# 0       0   0  0  0  2  0
# 1       0   0  0  0  0  1
# 2       6   0  0  0  0  1
# 3       0   0  0  0  0  4
# 4       0  20  0  2  0  2
# 5       0   0  0  7  0  0
# 6       0   0  2  0  0  0

# %% [markdown]
# Since we see that there is varaition in the two models, we need to compare them further to select one with more reasonable clustering

# %% [markdown]
# ## 5.2. Silhouette Scores Comparison

# %%
# Compute pairwise distances for hierarchical clustering
dist_matrix = pdist(df_pca, metric='euclidean')

# Hierarchical Clustering - Average Linkage with a cutoff at 2.1
linkage_average = linkage(dist_matrix, method='average')
labels_average = fcluster(linkage_average, t=7, criterion='maxclust')

# Compute silhouette score for average linkage clustering
silhouette_average = silhouette_score(df_pca, labels_average)
silhouette_vals_average = silhouette_samples(df_pca, labels_average)

# K-Means Clustering with 6 clusters
n_clusters = 6
kmeans = KMeans(n_clusters=n_clusters, n_init=20, random_state=rng)
labels_kmeans = kmeans.fit_predict(df_pca)

# Compute silhouette score for K-Means clustering
silhouette_kmeans = silhouette_score(df_pca, labels_kmeans)
silhouette_vals_kmeans = silhouette_samples(df_pca, labels_kmeans)

# Print Silhouette Scores
print(f"======= Silhouette Scores ======="
      f"\nK-Means      (6 clusters): {silhouette_kmeans:.5f}",
      f"\nHierarchical (7 clusters): {silhouette_average:.5f}",
      f"\n\nDifference               : {round((silhouette_average-silhouette_kmeans), 5)}")

# Create subplots for side-by-side comparison
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
# Plot silhouette scores for each clustering method in the respective subplot
plot_silhouette_hclust(axes[0], silhouette_vals_average, labels_average, "Silhouette Plot - Best Hierachical Model", 7, df_pca)
plot_silhouette(axes[1], silhouette_vals_kmeans, labels_kmeans, "Silhouette Plot - Best K-Means Model", 6, df_pca)

# Display the plots
plt.tight_layout()
plt.show()
# Out:
# ======= Silhouette Scores =======
# K-Means      (6 clusters): 0.37615
# Hierarchical (7 clusters): 0.37812
#
# Difference               : 0.00197

# %%
# Get the movie titles to find the misclassified movies
movie_titles = df_pca_titles['Title']

# Create silhouette DataFrame for HClust
df_silhouette_hclust = pd.DataFrame({
    'Index': np.arange(len(df_pca)),
    'Silhouette Score': silhouette_vals_average,
    'Cluster Label': labels_average
})

# Filter likely misclassified observations
misclassified_hclust = df_silhouette_hclust[df_silhouette_hclust['Silhouette Score'] < 0]

# Show count
print(f"Number of likely misclassified observations (HClust): {len(misclassified_hclust)}")

# Get and print titles of misclassified movies
misclassified_hclust_titles = movie_titles.iloc[misclassified_hclust['Index'].values]
print("\nMisclassified Movies (HClust):")
print(misclassified_hclust_titles)
# Out:
# Number of likely misclassified observations (HClust): 2
#
# Misclassified Movies (HClust):
# 17    Bahubali: The Beginning
# 29                Gran Torino
# Name: Title, dtype: object

# %% [markdown]
# # __6. Qualitative Clusters Analysis__

# %% [markdown]
# ## 6.1. K-Means

# %%
# Createa a new dataframe consisting of initially dropped variables from the data frame in attempt to classify the clusters
# Define variables for df
year = df['Year']
director = df['Director']
actors = df['Actors']
genres = df['Genre']

# Create DataFrame for cluster comparison
df_kmeans = pd.DataFrame({
    'Movie Title': movie_titles.values,
    'KMeans Cluster ID': labels_kmeans,
    'Year': year,
    'Director': director,
    'Actors': actors,
    'Genres': genres

})

# Sort the DataFrame by KMeans Cluster ID for easier interpretation
df_kmeans_sort = df_kmeans.sort_values(by='KMeans Cluster ID').reset_index(drop=True)

# Display the sorted DataFrame
df_kmeans_sort.head()  # head adde to reduce the footprint after observing the full data
# Out:
#        Movie Title  KMeans Cluster ID  Year            Director  \
# 0             Room                  0  2015    Lenny Abrahamson
# 1        Spotlight                  0  2015        Tom McCarthy
# 2          Warrior                  0  2011      Gavin O'Connor
# 3  Pan's Labyrinth                  0  2006  Guillermo del Toro
# 4        Incendies                  0  2010    Denis Villeneuve
#
#                                               Actors               Genres
# 0  Brie Larson, Jacob Tremblay, Sean Bridgers,Wen...                Drama
# 1  Mark Ruffalo, Michael Keaton, Rachel McAdams, ...  Crime,Drama,History
# 2  Tom Hardy, Nick Nolte, Joel Edgerton, Jennifer...   Action,Drama,Sport
# 3  Ivana Baquero, Ariadna Gil, Sergi López,Maribe...    Drama,Fantasy,War
# 4  Lubna Azabal, Mélissa Désormeaux-Poulin, Maxim...    Drama,Mystery,War

# %%
# Converst actors and genres insto a list of strings (initially single large string with commas seperation)
df_kmeans_top6 = df_kmeans_sort.copy()
df_kmeans_top6['Actors'] = split_and_strip(df_kmeans_top6['Actors'])
df_kmeans_top6['Genres'] = split_and_strip(df_kmeans_top6['Genres'])

# Create cluster-wise summary (top 6 most common values for each cluster)
cluster_summary = {}

# Iterate across the cluster IDs collecting and counting common values
for cluster_id, group in df_kmeans_top6.groupby('KMeans Cluster ID'):
    all_items_with_labels = []

    # Collect values with feature labels for the current cluster:
    all_items_with_labels += [(str(item), 'Year') for item in group['Year']]     # Years
    all_items_with_labels += [(item, 'Director') for item in group['Director']]  # Directors
    for actor_list in group['Actors']:                                           # Actors
        all_items_with_labels += [(actor, 'Actor') for actor in actor_list]
    for genre_list in group['Genres']:                                           # Genres
        all_items_with_labels += [(genre, 'Genre') for genre in genre_list]

    # Count and extract top 6 common values
    counter = Counter(all_items_with_labels)
    top_6 = counter.most_common(6)

    # Add to summary and the movies in that cluster movie titles
    cluster_summary[cluster_id] = {
        'Size': len(group),
        'Top Values': top_6,
        'Movie Titles': group['Movie Title'].tolist()
    }

# Print the obtained summary of common values and titles across clusters
for cluster_id, data in cluster_summary.items():
    print("============================")
    print(f"=== Cluster {cluster_id} (Size: {data['Size']}) ===")  # Cluster id and size
    for (value, feature), count in data['Top Values']:             # Top common values
        print(f"{value} ({feature}) — {count} times")
    print("\n== Movies in this cluster ==")
    for title in data['Movie Titles']:                             # Movies in the cluster
        print(f" - {title}")
    print("============================\n\n")
# Out:
# ============================
# === Cluster 0 (Size: 22) ===
# Drama (Genre) — 21 times
# Mystery (Genre) — 6 times
# 2016 (Year) — 4 times
# Crime (Genre) — 4 times
# Biography (Genre) — 4 times
# 2015 (Year) — 3 times
#
# == Movies in this cluster ==
#  - Room
#  - Spotlight
#  - Warrior
#  - Pan's Labyrinth
#  - Incendies
#  - El secreto de sus ojos
#  - PK
#  - Hacksaw Ridge
#  - Lion
#  - Prisoners
#  - The Help
#  - 12 Years a Slave
#  - No Country for Old Men
#  - Shutter Island
#  - Ah-ga-ssi
#  - Gone Girl
#  - Jagten
#  - Into the Wild
#  - Bahubali: The Beginning
#  - La La Land
#  - Taare Zameen Par
#  - 3 Idiots
# ============================
#
#
# ============================
# === Cluster 1 (Size: 6) ===
# Drama (Genre) — 4 times
# Leonardo DiCaprio (Actor) — 3 times
# 2012 (Year) — 2 times
# Christopher Nolan (Director) — 2 times
# Martin Scorsese (Director) — 2 times
# Quentin Tarantino (Director) — 2 times
#
# == Movies in this cluster ==
#  - Interstellar
#  - The Departed
#  - Inglourious Basterds
#  - The Dark Knight Rises
#  - Django Unchained
#  - The Wolf of Wall Street
# ============================
#
#
# ============================
# === Cluster 2 (Size: 9) ===
# Adventure (Genre) — 8 times
# Animation (Genre) — 5 times
# Comedy (Genre) — 4 times
# 2015 (Year) — 2 times
# 2008 (Year) — 2 times
# Pete Docter (Director) — 2 times
#
# == Movies in this cluster ==
#  - Inside Out
#  - Toy Story 3
#  - Zootopia
#  - Harry Potter and the Deathly Hallows: Part 2
#  - Mad Max: Fury Road
#  - WALL·E
#  - Gran Torino
#  - Guardians of the Galaxy
#  - Up
# ============================
#
#
# ============================
# === Cluster 3 (Size: 6) ===
# Drama (Genre) — 6 times
# 2016 (Year) — 2 times
# 2006 (Year) — 2 times
# Biography (Genre) — 2 times
# 2014 (Year) — 1 times
# 2011 (Year) — 1 times
#
# == Movies in this cluster ==
#  - Dangal
#  - Whiplash
#  - The Lives of Others
#  - The Prestige
#  - The Intouchables
#  - Kimi no na wa
# ============================
#
#
# ============================
# === Cluster 4 (Size: 2) ===
# Action (Genre) — 2 times
# 2012 (Year) — 1 times
# 2015 (Year) — 1 times
# Joss Whedon (Director) — 1 times
# J.J. Abrams (Director) — 1 times
# Robert Downey Jr. (Actor) — 1 times
#
# == Movies in this cluster ==
#  - The Avengers
#  - Star Wars: Episode VII - The Force Awakens
# ============================
#
#
# ============================
# === Cluster 5 (Size: 2) ===
# Christopher Nolan (Director) — 2 times
# Action (Genre) — 2 times
# 2010 (Year) — 1 times
# 2008 (Year) — 1 times
# Leonardo DiCaprio (Actor) — 1 times
# Joseph Gordon-Levitt (Actor) — 1 times
#
# == Movies in this cluster ==
#  - Inception
#  - The Dark Knight
# ============================

# %% [markdown]
# ## 6.2. Hierarchical

# %%
# Create a new dataframe consisting of initially dropped variables from the data frame in attempt to classify the clusters
# Define variables for df
movie_titles = df_pca_titles['Title']  # Adjust if your titles are stored elsewhere
year = df['Year']
director = df['Director']
actors = df['Actors']
genres = df['Genre']

# Create DataFrame for cluster comparison
df_hclust = pd.DataFrame({
    'Movie Title': movie_titles.values,
    'Hierarchical Cluster ID': labels_average,
    'Year': year,
    'Director': director,
    'Actors': actors,
    'Genres': genres
})

# Sort the DataFrame by Hierarchical Cluster ID for easier interpretation
df_hclust_sort = df_hclust.sort_values(by='Hierarchical Cluster ID').reset_index(drop=True)

# Display the sorted DataFrame
df_hclust_sort.head()  # head added to reduce the footprint after observing the full data
# Out:
#                                   Movie Title  Hierarchical Cluster ID  Year  \
# 0                             The Dark Knight                        1  2008
# 1                                   Inception                        1  2010
# 2                                The Avengers                        2  2012
# 3  Star Wars: Episode VII - The Force Awakens                        2  2015
# 4                                 Toy Story 3                        3  2010
#
#             Director                                             Actors  \
# 0  Christopher Nolan  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...
# 1  Christopher Nolan  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# 2        Joss Whedon  Robert Downey Jr., Chris Evans, Scarlett Johan...
# 3        J.J. Abrams  Daisy Ridley, John Boyega, Oscar Isaac, Domhna...
# 4        Lee Unkrich      Tom Hanks, Tim Allen, Joan Cusack, Ned Beatty
#
#                        Genres
# 0          Action,Crime,Drama
# 1     Action,Adventure,Sci-Fi
# 2               Action,Sci-Fi
# 3    Action,Adventure,Fantasy
# 4  Animation,Adventure,Comedy

# %%
# Converst actors and genres insto a list of strings (initially single large string with commas seperation)
df_hclust_top6 = df_hclust_sort.copy()
df_hclust_top6['Actors'] = split_and_strip(df_hclust_top6['Actors'])
df_hclust_top6['Genres'] = split_and_strip(df_hclust_top6['Genres'])

# Create cluster-wise summary (top 6 most common values for each cluster)
cluster_summary = {}

# Iterate across the cluster IDs collecting and counting common values
for cluster_id, group in df_hclust_top6.groupby('Hierarchical Cluster ID'):
    all_items_with_labels = []

    # Collect values with feature labels for the current cluster:
    all_items_with_labels += [(str(item), 'Year') for item in group['Year']]     # Years
    all_items_with_labels += [(item, 'Director') for item in group['Director']]  # Directors
    for actor_list in group['Actors']:                                           # Actors
        all_items_with_labels += [(actor, 'Actor') for actor in actor_list]
    for genre_list in group['Genres']:                                           # Genres
        all_items_with_labels += [(genre, 'Genre') for genre in genre_list]

    # Count and extract top 6 common values
    counter = Counter(all_items_with_labels)
    top_6 = counter.most_common(6)

    # Add to summary and the movies in that cluster
    cluster_summary[cluster_id] = {
        'Size': len(group),
        'Top Values': top_6,
        'Movie Titles': group['Movie Title'].tolist()
    }

# Print the obtained summary of common values and titles across clusters
for cluster_id, data in cluster_summary.items():
    print("============================")
    print(f"=== Cluster {cluster_id} (Size: {data['Size']}) ===")  # Cluster id and size
    for (value, feature), count in data['Top Values']:             # Top common values
        print(f"{value} ({feature}) — {count} times")
    print("\n== Movies in this cluster ==")
    for title in data['Movie Titles']:                             # Movies in the cluster
        print(f" - {title}")
    print("============================\n\n")
# Out:
# ============================
# === Cluster 1 (Size: 2) ===
# Christopher Nolan (Director) — 2 times
# Action (Genre) — 2 times
# 2008 (Year) — 1 times
# 2010 (Year) — 1 times
# Christian Bale (Actor) — 1 times
# Heath Ledger (Actor) — 1 times
#
# == Movies in this cluster ==
#  - The Dark Knight
#  - Inception
# ============================
#
#
# ============================
# === Cluster 2 (Size: 2) ===
# Action (Genre) — 2 times
# 2012 (Year) — 1 times
# 2015 (Year) — 1 times
# Joss Whedon (Director) — 1 times
# J.J. Abrams (Director) — 1 times
# Robert Downey Jr. (Actor) — 1 times
#
# == Movies in this cluster ==
#  - The Avengers
#  - Star Wars: Episode VII - The Force Awakens
# ============================
#
#
# ============================
# === Cluster 3 (Size: 7) ===
# Adventure (Genre) — 7 times
# Animation (Genre) — 5 times
# Comedy (Genre) — 4 times
# Pete Docter (Director) — 2 times
# 2010 (Year) — 1 times
# 2011 (Year) — 1 times
#
# == Movies in this cluster ==
#  - Toy Story 3
#  - Harry Potter and the Deathly Hallows: Part 2
#  - Up
#  - Guardians of the Galaxy
#  - Zootopia
#  - Inside Out
#  - WALL·E
# ============================
#
#
# ============================
# === Cluster 4 (Size: 22) ===
# Drama (Genre) — 20 times
# Mystery (Genre) — 6 times
# 2015 (Year) — 4 times
# 2016 (Year) — 4 times
# Crime (Genre) — 4 times
# Biography (Genre) — 4 times
#
# == Movies in this cluster ==
#  - Gran Torino
#  - Incendies
#  - El secreto de sus ojos
#  - PK
#  - Mad Max: Fury Road
#  - Gone Girl
#  - Prisoners
#  - The Help
#  - 12 Years a Slave
#  - No Country for Old Men
#  - Shutter Island
#  - Ah-ga-ssi
#  - Lion
#  - Pan's Labyrinth
#  - Room
#  - Spotlight
#  - Warrior
#  - La La Land
#  - Bahubali: The Beginning
#  - Into the Wild
#  - Jagten
#  - Hacksaw Ridge
# ============================
#
#
# ============================
# === Cluster 5 (Size: 5) ===
# Drama (Genre) — 5 times
# 2006 (Year) — 2 times
# 2014 (Year) — 1 times
# 2011 (Year) — 1 times
# 2016 (Year) — 1 times
# Damien Chazelle (Director) — 1 times
#
# == Movies in this cluster ==
#  - Whiplash
#  - The Prestige
#  - The Intouchables
#  - Kimi no na wa
#  - The Lives of Others
# ============================
#
#
# ============================
# === Cluster 6 (Size: 3) ===
# Aamir Khan (Actor) — 3 times
# Drama (Genre) — 3 times
# 2009 (Year) — 1 times
# 2007 (Year) — 1 times
# 2016 (Year) — 1 times
# Rajkumar Hirani (Director) — 1 times
#
# == Movies in this cluster ==
#  - 3 Idiots
#  - Taare Zameen Par
#  - Dangal
# ============================
#
#
# ============================
# === Cluster 7 (Size: 6) ===
# Drama (Genre) — 4 times
# Leonardo DiCaprio (Actor) — 3 times
# 2012 (Year) — 2 times
# Quentin Tarantino (Director) — 2 times
# Martin Scorsese (Director) — 2 times
# Christopher Nolan (Director) — 2 times
#
# == Movies in this cluster ==
#  - Django Unchained
#  - The Wolf of Wall Street
#  - The Dark Knight Rises
#  - The Departed
#  - Interstellar
#  - Inglourious Basterds
# ============================
